# %% [markdown]
# <a href="https://colab.research.google.com/github/Guilherme-Brasil/Relatorio-de-Vendas-2018/blob/main/An%C3%A1lise_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01. Analisar os arquivos que contém a base de dados.
import os
import pandas as pd
import plotly.express as px

lista_arquivos = os.listdir("/content/drive/MyDrive/Vendas")
display(lista_arquivos)
# Out:
# ['Devolucoes - Rio de Janeiro.csv',
#  'Vendas - São Paulo.csv',
#  'Vendas - Porto Alegre.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Goiás.csv',
#  'Vendas - Fortaleza.csv',
#  'Vendas - Recife.csv',
#  'Vendas - Goiás.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Vendas - Curitiba.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - São Paulo.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Salvador.csv',
#  'Devolucoes - Porto Alegre.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Devolucoes - Curitiba.csv']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tabela_total = pd.DataFrame()

#02. Importar as bases de dados.
for arquivo in lista_arquivos:
  if "Vendas" in arquivo:
    #Importando o arquivo
    tabela = pd.read_csv(f"/content/drive/MyDrive/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)

#03. Tratar/Compilar as bases de dados.
display(tabela_total)
# Out:
# <ipython-input-7-b7a65dfcd002>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# <ipython-input-7-b7a65dfcd002>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# <ipython-input-7-b7a65dfcd002>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# <ipython-input-7-b7a65dfcd002>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tabela_total = tabela_total.append(tabela)
# ...

# %%
#04. Calcular o produto mais vendido (Quantidade).
tabela_produtos = tabela_total.groupby('Produto').sum()
tabela_produtos = tabela_produtos[["Quantidade Vendida"]].sort_values(by = "Quantidade Vendida", ascending = False)
display(tabela_produtos)
# Out:
#             Quantidade Vendida
# Produto
# iPhone                    8974
# Televisão                 5931
# Notebook                  3249
# Android                   3183
# SmartWatch                2980
# Tablet                    2921
# Câmera                    2805

# %%
#05. Calcular o produto de maior faturamento (Faturamento).
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Faturamento"]].sort_values(by = "Faturamento", ascending = False)
display(tabela_faturamento)
# Out:
#             Faturamento
# Produto
# iPhone         47562200
# Televisão      14827500
# Notebook       11371500
# Android        10822200
# Câmera          5890500
# Tablet          4673600
# SmartWatch      4172000

# %%
#06. Calcular a loja/cidade que mais vendeu (Faturamento).
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
#07. Gerar um gráfico/dashboard.
grafico = px.bar(tabela_lojas, x = tabela_lojas.index, y = 'Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
